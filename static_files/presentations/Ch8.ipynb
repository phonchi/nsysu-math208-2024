# %% [markdown]
# # Exercise 8

# %% [markdown]
# ### (1)  What is the big O of the Knight's Tour function where `k` is a small constant, and `n` is the total number of vertices (or spaces on a chessboard)?
#
# (A) $O(k^n)$
#
# (B) $O(n)$
#
# (C) $O(n^2)$
#
# (D) $O(n!)$

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# ### (2)  What purpose does the Priority Queue in the Dijkstra's algorithm serve?
#
# (A) It only holds a series of vertices to traverse.
#
# (B) It holds an unsorted list of unvisited vertices.
#
# (C) It notes what vertices have been visited.
#
# (D) It holds an appropriately sorted list of vertices to traverse.

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# ### (3) Beginning at node E, how will Prim's algorithm span across the graph?
#
# ![image.png](attachment:image.png)
#
# (A) `{E, D, A, B, C}`
#
# (B) `{E, C, B, A, D}`
#
# (C) `{E, C, B, D, A}`
#
# (D) `{E, D, A, B, C}`

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# ### (4) Which of the following statemnet is incorrect?

# %% [markdown]
# (A) The output of DFS and the output of BFS on an undirected graph `G` can not uniquely define the structure of `G`.
#
# (B) A tree is a connected graph without cycles.
#
# (C) A spanning tree of a grapg G is a subgraph of G without cycles that has maximum total edge weights.
#
# (D) A connected graph with $n$ vertices and $n-1$ edges must be a tree.

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# ### (5) Given a weighted directed graph with negative edges as follows, what is the cost of the shortes path from vertex A to each vertex (in the order of A, B, C, D, E, F, G), after performing Dijkstra's algorithm
#
# ![image.png](attachment:image.png)
#
# (A) `0, 2, 7, 2, 9, 6, 2`
#
# (B) `0, 2, 7, 2, 9, 4, 2`
#
# (C) `0, 2, 7, 2, 9, 4, 8`
#
# (D) `0, 2, 7, 4, 9, 6, 2`

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# ### (6) Which of the following statement is TRUE?
#
# (A) Stack is used to hold nodes in BFS of a graph.
#
# (B) In BFS, we process all of a node's descendants before we move to and adjacent node.
#
# (C) DFS is usually used to find the shortes path between two nodes in a graph.
#
# (D) DFS can be used to solve the Knight's tour problem.

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# ### (7) Which of the following statement is TRUE?
#
# (A) When the input graph is DAG, then the shortest path can be found in $O(V+E)$ using Dijkstra algorithm.
#
# (B) The Dijkstra algorithm can not find the shortest path correctly when there is a cycle
#
# (C) The time complexity of DFS is $O(V+E)$
#
# (D) The time complexity of BFS is $O(V*E)$

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# ### (8) What is the cost of minimum spanning tree of the graph
#
# ![image.png](attachment:image.png)
#
# (A) 28
#
# (B) 30
#
# (C) 32
#
# (D) 33

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# ### (9) What is the main differences between DFS and BFS in a graph?

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# ### (10) What is the Big-O running time for Prim's minimum spanning tree algorithm?

# %% [markdown]
# > Ans: *Double click to answer the question*

# %% [markdown]
# ### (11) Explain why Dijkstra's algorithm can not work in a graph with a negative edge for finding the shortest path

# %% [markdown]
# > Ans: *Double click to answer the question*
